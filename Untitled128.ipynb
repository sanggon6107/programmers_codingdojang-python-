# %%
import re
import cv2
from pytesseract import *
from PIL import Image

#img = Image.open('ocrtest.jpg')
img = cv2.imread('ocrtest.jpg')

text = pytesseract.image_to_string(img,lang='kor')

print(text)
# Out:
# 26121 빠(가기/^11041
#
#
#
#
#
# 머깨너비
#
# 으쁘무+
#
#
#
# 912 바0(단위:00)
#
# 사이즈(5126)          055            066            067
# 어깨너비            37.5            38.6            39.4
# 가슴둘레            88.3            93.6            98.4
# 소매길이             61             61.7            64.5
#
# 총장              67.3            67.9            68.6
# - 사이즈는 재는 방법에 따라 1~207 정도 오차가 있을 수 있습니다.
#
#
#
# 5\41<82
# 더블 브레스티드 자켓
# 60108    8티66(25)/0기497(47)
#
# 91깨       05570667067
#
# 마141Ｌ 다
#
# 뱅시오
#
# - 뒤집어 단독세탁하십시오.
# - 세탁시 이염될 우려가 있 으니 주의 바랍니다.
# - 모든 의류의 첫 세탁은 드라이클리닝을 권장합니다.
#
#
#
#
#
#
#
#
#
#
#
# 가          . 데님, 워싱, 컬러가 있는 모든 제품들은 단독 세탁을 권장하며
# 내 8 9                                     세탁 부주의로 인해 훼손이 있을 경우 교환, 반품이 불가하오니
# 참고해주세요.
# 두께감                                                      로
# (101000659)                     얄음(10)               보통(1006「216)              도톰(100
# 비침                            애
# (566 01104910)                     없음(4006)                 살짝(니네)                비침(1060)
# 촉감                                                       1
# (티85400                               부드러움(50[ㅁ0                     보통1006「216)                       까슬함(0000
# 비가                                                       애
# (000009)                     타이트(7914               기본(5049 00              루즈(0056)
# 신축성                                                      ㆍ
# (티65000)                     없음(0006)               보통(0006「316)              높음(1191)
# 만건                            애
# (000009)                      있음(1060)                   없음(0006)
# 원산지        베트남                                     아60<ㅠ
# 제조년월일 ㅣ 2019년 02월
# 원단/부자재/봉제 불량은 구입일로부터 1년 이내 무상수선, 교환
#
# 겨
# 보
#
# (주)동광인터내셔날
#
# 구입일로부터 1년
#
# 매
# 뜨
# ㅁ
# 맨
# 고
# 2
#
# .^/5 책임자       (주)동광인터내셔날 / 1588-2724
#
# 또는 환불이 가능합니다.
#
# 단, 봉제 불량은 1년 경과 후에도 무상
# 소비자 부주의로 인한       환, 반품 처리가 불가하며 수리 가
# 능시에는 유상 수리로 진행됩니다.
#
# 모델컷의 컬러는 자연광이나 조명의 영향으로 실제와 다소 다를
# 수 있습니다. 꼭 디테일 컬러와 소재를 확인해주세요.
#
# 수리 진행됩니다.
