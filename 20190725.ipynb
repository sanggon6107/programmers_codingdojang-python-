# %%
print("="*50, "2019.07.25", "="*50)

import csv
from matplotlib import pyplot as plt
import random

i = 0
j = 0
k = 0
l = 0

ITERATION_000 = 0
ITERATION_DATA_000 = []

ITERATION_001 = 0
ITERATION_DATA_001 = []

ITERATION_002 = 0
ITERATION_DATA_002 = []

ITERATION_003 = 0
ITERATION_DATA_003 = []

for i in range(1, 11):
    ITERATION_000 = random.randint(1, 6)
    ITERATION_DATA_000.append(ITERATION_000)
    
for j in range(1, 101):
    ITERATION_001 = random.randint(1, 6)
    ITERATION_DATA_001.append(ITERATION_001)

for k in range(1, 1001):
    ITERATION_002 = random.randint(1, 6)
    ITERATION_DATA_002.append(ITERATION_002)

for l in range(1, 10001):
    ITERATION_003 = random.randint(1, 6)
    ITERATION_DATA_003.append(ITERATION_003)

    
plt.figure(1, figsize = (12, 12))

hs1 = plt.subplot(2, 2, 1)
plt.title("ITERATION=10")
plt.hist(ITERATION_DATA_000, bins = 6, label = "10")

hs2 = plt.subplot(2, 2, 2)
plt.title("ITERATION=100")
plt.hist(ITERATION_DATA_001, bins = 6, label = "100")

hs3 = plt.subplot(2, 2, 3)
plt.title("ITERATION=1000")
plt.hist(ITERATION_DATA_002, bins = 6, label = "1000")

hs4 = plt.subplot(2, 2, 4)
plt.title("ITERATION=10000")
plt.hist(ITERATION_DATA_003, bins = 6, label = "10000")


plt.show
# Out:
# ================================================== 2019.07.25 ==================================================
# <function matplotlib.pyplot.show(*args, **kw)>
