# %%
print("="*50, "2019.07.19", "="*50)

import csv
import numpy as np
import sys
import pandas as pd

row = 0;

F_file = open("D:extremum_20190718101759.csv", 'r')

file_DATA = csv.reader(F_file, delimiter = ",")   #readlines()함수와 비슷하지만,전체 데이터를 리스트로 저장한 다음, 
##다시 각 행의 데이터를 리스트형식으로 return

for row in file_DATA:
    print(row)

F_file.close()

print("\n\n", "="*100, "\n\n")

L_file = open("D:extremum_20190718101759.csv", 'r')

li_DATA = L_file.readlines()

for line_DATA in li_DATA:
    print(line_DATA)
    
L_file.close()
# Out:
# ================================================== 2019.07.19 ==================================================
# ['\t\t지점번호', '지점명', '일시', '평균기온(℃)', '최고기온(℃)', '\t최고기온시각', '최저기온(℃)', '최저기온시각']
# ['\t\t159', '부산', '2019-06-01', '19.8', '24.8', '14:04', '16.2', '5:13']
# ['\t\t159', '부산', '2019-06-02', '20.9', '24.6', '10:04', '17.4', '23:58']
# ['\t\t159', '부산', '2019-06-03', '21.3', '25.6', '13:26', '17.4', '0:01']
# ['\t\t159', '부산', '2019-06-04', '23.4', '26.5', '14:11', '19.2', '0:01']
# ['\t\t159', '부산', '2019-06-05', '23.9', '29.7', '9:57', '20.4', '5:07']
# ['\t\t159', '부산', '2019-06-06', '22.1', '27', '14:09', '17.8', '23:47']
# ['\t\t159', '부산', '2019-06-07', '18.7', '20', '15:57', '16.8', '0:25']
# ['\t\t159', '부산', '2019-06-08', '19.1', '22.2', '14:10', '17', '23:57']
# ['\t\t159', '부산', '2019-06-09', '18.5', '22.1', '12:42', '16.4', '2:21']
# ['\t\t159', '부산', '2019-06-10', '18.8', '22.7', '9:59', '15.8', '4:48']
# ...
