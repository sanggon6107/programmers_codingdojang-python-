# %%
'''
2019. 6. 27
'''

print("="*10, "\n\nHello world!\n")
print("="*10, "\n\n")


import numpy as np
import sys


n=0
taishou=0
shou=0
nokori=0
saishuu=0

while n<13:
    n=n+1
    taishou=2**n
    print("2^",n,"=", taishou)
    shou=taishou//3
    nokori=taishou%3
    saishuu=3*shou+nokori
    print(taishou,"/3=   3x", shou, "+", nokori, "=", saishuu,"\n\n" )
    
#괄포 이용하면 함수. 특히, print는 파이썬3부터 함수 취급하므로 print()로 표기하여야함.  
sum = 0
for k in range(1, 100):
    sum=sum+k
print("sum=", sum)

print("-"*100)
print("\n\n")

a="Sometimes"
A=np.zeros((1, len(a)))
print(A)

count=0
#성분은 대괄호, 함수는 소괄호
for count in range(0, len(a)):
    A[0, count]=count+1
#문자열 인덱싱, 개행제거 프린트(import sys 필요)
    sys.stdout.write(a[count])
    

#문자열 슬라이싱
a1=a[:3]
a2=a[4:]
print("\n", a1, a2)

#문자열 포매팅
print("F O R M %s T %s I N %s" %("A", "T", "G") )

#f문자열 포매팅
f'{"hi":!<50}'
f'{"hi":=^50}'

#카운트 및 파인드

aaa="e oi8eh;fhigosdhizobfiovliklwegbiklrawelhouilxbfolxihguierhguiarhsd"
aaa.find("8")
numberk=aaa.count("k")
print("The number of the k in the string above is %d" % numberk)
# Out:
# ...
#
# Hello world!
#
# ...
#
#
# 2^ 1 = 2
# 2 /3=   3x 0 + 2 = 2
#
#
# 2^ 2 = 4
# 4 /3=   3x 1 + 1 = 4
#
#
# 2^ 3 = 8
# 8 /3=   3x 2 + 2 = 8
#
#
# 2^ 4 = 16
# 16 /3=   3x 5 + 1 = 16
#
#
# 2^ 5 = 32
# 32 /3=   3x 10 + 2 = 32
#
#
# 2^ 6 = 64
# 64 /3=   3x 21 + 1 = 64
#
#
# 2^ 7 = 128
# 128 /3=   3x 42 + 2 = 128
#
#
# 2^ 8 = 256
# 256 /3=   3x 85 + 1 = 256
#
#
# 2^ 9 = 512
# 512 /3=   3x 170 + 2 = 512
#
#
# 2^ 10 = 1024
# 1024 /3=   3x 341 + 1 = 1024
#
#
# 2^ 11 = 2048
# 2048 /3=   3x 682 + 2 = 2048
#
#
# 2^ 12 = 4096
# 4096 /3=   3x 1365 + 1 = 4096
#
#
# 2^ 13 = 8192
# 8192 /3=   3x 2730 + 2 = 8192
#
#
# sum= 4950
# ----------------------------------------------------------------------------------------------------
#
#
#
# [[0. 0. 0. 0. 0. 0. 0. 0. 0.]]
# Sometimes
#  Som times
# F O R M A T T I N G
# The number of the k in the string above is 2
