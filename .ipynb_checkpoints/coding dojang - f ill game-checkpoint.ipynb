# %%
s = '''
OOOOO
XOOXO
OOOOO
OOOOO
OOOOX
'''

def check(data) :  # 완료 여부 확인
    for line in data :
        if 'O' in line : return False
    return True
    
    
    return 


p__= '''BFS로 구현. maximum depth가 정해져 있음에도 DFS나 백트래킹으로 구현할 경우 왜 stack overflow가 발생할 수 있는가?'''

map_ = list(map(list, s.split()))
x_pos, y_pos = 0, 0




def bfs(mapp, x_pos, y_pos) :
    queue = [mapp]
    while len(queue) != 0 :
        
    
    return 

bfs(map_, x_pos, y_pos)
# Out:
# [['O', 'O', 'O', 'O', 'O'],
#  ['X', 'O', 'O', 'X', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'X']]

# %%
s = '''
OOOOO
OOOXO
OOOOO
OOOOO
OOOOX
'''

def check(data) :  # 완료 여부 확인
    count = 0
    for line in data[:-1] :
        if 'O' in line : count += 1
    if count == 1 : return True
    else : return False



p__= '''BFS로 구현. maximum depth가 정해져 있음에도 DFS나 백트래킹으로 구현할 경우 왜 stack overflow가 발생할 수 있는가?'''

x_pos, y_pos = 0, 0
map_ = list(map(list, s.split()))+[[x_pos, y_pos]]


def bfs(mapp) :
    queue = [mapp]
    while len(queue) != 0 :
        tem_map = queue.pop(0)
        ten_x, ten_y = tem_map[-1][0], tem_map[-1][1]
        
        if check(tem_map) == True : print(tem_map)
        else :
            
            if 0<tem_map[-1][1] and tem_map[tem_map[-1][1]-1][tem_map[-1][0]] == 'O' :
#                print(True)#위 탐색, x좌표 y좌표 반전 주의
                tem_map[tem_map[-1][1]][tem_map[-1][0]] = 'U'
                tem_map[-1][0], tem_map[-1][1] = ten_x, ten_y-1
                queue.append(tem_map)
            if tem_map[-1][1] < len(tem_map)-2 and tem_map[tem_map[-1][1]+1][tem_map[-1][0]] == 'O' :
#                print(True)#아래 탐색
                tem_map[tem_map[-1][1]][tem_map[-1][0]] = 'D'
                tem_map[-1][0], tem_map[-1][1] = ten_x, ten_y+1
                queue.append(tem_map)
            if 0 < mapp[-1][0] and tem_map[tem_map[-1][1]][tem_map[-1][0]-1] == 'O' : 
#                print(True)#왼쪽 탐색
                tem_map[tem_map[-1][1]][tem_map[-1][0]] = 'L'
                tem_map[-1][0], tem_map[-1][1] = ten_x-1, ten_y
                queue.append(tem_map)
            if mapp[-1][0] < len(tem_map[0])-2 and tem_map[tem_map[-1][1]][tem_map[-1][0]+1] == 'O' :
#                print(True)#오른쪽 탐색
                tem_map[tem_map[-1][1]][tem_map[-1][0]] = 'R'
                tem_map[-1][0], tem_map[-1][1] = ten_x+1, ten_y
                queue.append(tem_map)
        print(queue)
        break
### 한 루프 안에 방향을 여러개 두면, 현재 위치를 저장할 수 없다. queue안의 각 데이터별로 x_pos, y_pos이 달라지므로 
### 리스트형 자료 안에 x, y 저장하는 방법 고려해볼 것.
    
    return 0

bfs(map_)
# Out:
# [[['D', 'O', 'O', 'O', 'O'], ['R', 'O', 'O', 'X', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'X'], [1, 0]], [['D', 'O', 'O', 'O', 'O'], ['R', 'O', 'O', 'X', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'X'], [1, 0]]]
# 0

# %%
s = '''
OOOOO
OOOXO
OOOOO
OOOOO
OOOOX
'''

def check(data) :  # 완료 여부 확인
    count = 0
    for line in data[:-1] :
        if 'O' in line : count += 1
    if count == 1 : return True
    else : return False



p__= '''BFS로 구현. maximum depth가 정해져 있음에도 DFS나 백트래킹으로 구현할 경우 왜 stack overflow가 발생할 수 있는가?'''

x_pos, y_pos = 0, 0
map_ = list(map(list, s.split()))+[[x_pos, y_pos]]


def bfs(mapp) :
    queue = [mapp]
    while len(queue) != 0 :
        tem_map = queue.pop(0)
        ten_x, ten_y = tem_map[-1][0], tem_map[-1][1]  # 자료 정보를 ten_x, ten_y에 저장
        
        if check(tem_map) == True : print(tem_map) #모두 채워진 경우 출력

        else :
            if 0 < ten_y and tem_map[ten_y-1][ten_x] == 'O' :
#                print(True)#위 탐색, x좌표 y좌표 반전 주의
                tem_map[ten_y][ten_x] = 'U'
                tem_map[-1][0], tem_map[-1][1] = ten_x, ten_y-1
                queue.append(tem_map)
                print(queue)
            
            if ten_y < len(tem_map)-2 and tem_map[ten_y+1][ten_x] == 'O' :
#                print(True)#아래 탐색
                tem_map[ten_y][ten_x] = 'D'
                tem_map[-1][0], tem_map[-1][1] = ten_x, ten_y+1
                queue.append(tem_map)

                print(queue)
            print("D")
            if 0 < ten_x and tem_map[ten_y][ten_x-1] == 'O' : 
#                print(True)#왼쪽 탐색
                tem_map[ten_y][ten_x] = 'L'
                tem_map[-1][0], tem_map[-1][1] = ten_x-1, ten_y
                queue.append(tem_map)
                print(queue)
            
            if ten_x < len(tem_map[0])-2 and tem_map[ten_y][ten_x+1] == 'O' :
#                print(True)#오른쪽 탐색
                tem_map[ten_y][ten_x] = 'R'
                tem_map[-1][0], tem_map[-1][1] = ten_x+1, ten_y
                queue.append(tem_map)
                print(queue)
        print(queue)
        # 반복문을 전부 읽은 다음 처리하는 듯 하다. 인터프리터는 #############################
        # print()호출 시에는 인스턴스 겹치지 않는다. #############################
        break
### 한 루프 안에 방향을 여러개 두면, 현재 위치를 저장할 수 없다. queue안의 각 데이터별로 x_pos, y_pos이 달라지므로 
### 리스트형 자료 안에 x, y 저장하는 방법 고려해볼 것.
    
    return 0

bfs(map_)
# Out:
# [['D', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'X', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'X'], [0, 1]]
# D
# [['R', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'X', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'X'], [1, 0], ['R', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'X', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'X'], [1, 0]]
# [['R', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'X', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'X'], [1, 0], ['R', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'X', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'X'], [1, 0]]
# 0

# %%
s = '''
OOOOO
OOOXO
OOOOO
OOOOO
OOOOX
'''

def check(data) :  # 완료 여부 확인
    count = 0
    for line in data[:-1] :
        if 'O' in line : count += 1
    if count == 1 : return True
    else : return False



p__= '''BFS로 구현. maximum depth가 정해져 있음에도 DFS나 백트래킹으로 구현할 경우 왜 stack overflow가 발생할 수 있는가?'''

x_pos, y_pos = 0, 0
map_ = list(map(list, s.split()))+[[x_pos, y_pos]]


def bfs(mapp) :
    queue = [mapp]
    while len(queue) != 0 :
        tem_map = queue.pop(0)
        ten_x, ten_y = tem_map[-1][0], tem_map[-1][1]
        
        if check(tem_map) == True : print(tem_map)
        else :
            if 0<ten_y and tem_map[ten_y-1][ten_x] == 'O' :
#                print(True)#위 탐색, x좌표 y좌표 반전 주의
                tem_map[ten_y][ten_x] = 'U'
                tem_map[-1][0], tem_map[-1][1] = ten_x, ten_y-1
                queue.append(tem_map)
            if ten_y < len(tem_map)-2 and tem_map[ten_y+1][ten_x] == 'O' :
#                print(True)#아래 탐색
                tem_map[ten_y][ten_x] = 'D'
                tem_map[-1][0], tem_map[-1][1] = ten_x, ten_y+1
                queue.append(tem_map)
            if 0 < ten_x and tem_map[ten_y][ten_x-1] == 'O' : 
#                print(True)#왼쪽 탐색
                tem_map[ten_y][ten_x] = 'L'
                tem_map[-1][0], tem_map[-1][1] = ten_x-1, ten_y
                queue.append(tem_map)
            if ten_x < len(tem_map[0])-2 and tem_map[ten_y][ten_x+1] == 'O' :
#                print(True)#오른쪽 탐색
                tem_map[ten_y][ten_x] = 'R'
                tem_map[-1][0], tem_map[-1][1] = ten_x+1, ten_y
                #queue.append(tem_map)
        print(queue)
        # 반복문을 전부 읽은 다음 처리하는 듯 하다. 인터프리터는 #############################
        break
### 한 루프 안에 방향을 여러개 두면, 현재 위치를 저장할 수 없다. queue안의 각 데이터별로 x_pos, y_pos이 달라지므로 
### 리스트형 자료 안에 x, y 저장하는 방법 고려해볼 것.
    
    return 0

bfs(map_)
# Out:
# [[['R', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'X', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'X'], [1, 0]]]
# 0

# %%
s = '''
OOOOO
OOOXO
OOOOO
OOOOO
OOOOX
'''

def check(data) :  # 완료 여부 확인
    count = 0
    for line in data[:-1] :
        if 'O' in line : count += 1
    if count == 1 : return True
    else : return False



p__= '''BFS로 구현. maximum depth가 정해져 있음에도 DFS나 백트래킹으로 구현할 경우 왜 stack overflow가 발생할 수 있는가?'''

x_pos, y_pos = 0, 0
map_ = list(map(list, s.split()))+[[x_pos, y_pos]]


def bfs(mapp) :
    queue = [mapp]
    while len(queue) != 0 :
        ss = queue.pop(0)
        #print("pop, queue : ", ss, queue)
        ten_x, ten_y = ss[-1][0], ss[-1][1]  # 자료 정보를 ten_x, ten_y에 저장
        d = input("Idddddd")
        if check(ss) == True : 
            print("check done", ss) #모두 채워진 경우 출력
            continue

        else :
            for cond in ((-1, 0, ten_y, 'U'), (1, 0, len(ss)-2-ten_y, 'D'), (0, -1, ten_x, 'L'), (0, 1, len(ss[0])-2-ten_x, 'R')) : # y, x, Constraint, ''  ## Constraint는 0 < C 로 설정한다
                tem_map = ss
                #print(tem_map)
                if cond[2] > 0 and tem_map[ten_y+cond[0]][ten_x+cond[1]] == 'O' :
                    tem_map[ten_y][ten_x] = cond[3]
                    tem_map[-1][0], tem_map[-1][1] = ten_x + cond[1], ten_y + cond[0]
                    queue.append(tem_map)
                print(ss)
                tem_map = 1
                print(ss, "DONE")
        print("while Done")
        #print(queue)
        # 반복문을 전부 읽은 다음 처리하는 듯 하다. 인터프리터는 #############################
        # print()호출 시에는 인스턴스 겹치지 않는다. #############################
### 한 루프 안에 방향을 여러개 두면, 현재 위치를 저장할 수 없다. queue안의 각 데이터별로 x_pos, y_pos이 달라지므로 
### 리스트형 자료 안에 x, y 저장하는 방법 고려해볼 것.
    
    return 0

bfs(map_)
# Out:
# Iddddddd
# [['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'X', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'X'], [0, 0]]
# [['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'X', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'X'], [0, 0]] DONE
# [['D', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'X', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'X'], [0, 1]]
# [['D', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'X', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'X'], [0, 1]] DONE
# [['D', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'X', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'X'], [0, 1]]
# [['D', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'X', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'X'], [0, 1]] DONE
# ...

# %%
s = '''
OOOOO
OOOXO
OOOOO
OOOOO
OOOOX
'''

def check(data) :  # 완료 여부 확인
    count = 0
    for line in data[:-1] :
        if 'O' in line : count += 1
    if count == 1 : return True
    else : return False



p__= '''BFS로 구현. maximum depth가 정해져 있음에도 DFS나 백트래킹으로 구현할 경우 왜 stack overflow가 발생할 수 있는가?'''

x_pos, y_pos = 0, 0
map_ = list(map(list, s.split()))+[[x_pos, y_pos]]


def bfs(mapp) :
    queue = [mapp]
    while len(queue) != 0 :
        ss = queue.pop(0)
        #print("pop, queue : ", ss, queue)
        ten_x, ten_y = ss[-1][0], ss[-1][1]  # 자료 정보를 ten_x, ten_y에 저장
        if check(ss) == True : 
            print("check done", ss) #모두 채워진 경우 출력
            continue
        else :
            for cond in ((-1, 0, ten_y, 'U'), (1, 0, len(ss)-2-ten_y, 'D'), (0, -1, ten_x, 'L'), (0, 1, len(ss[0])-2-ten_x, 'R')) : # y, x, Constraint, ''  ## Constraint는 0 < C 로 설정한다
                tem_map = ss
                #print(tem_map)
                if cond[2] > 0 and tem_map[ten_y+cond[0]][ten_x+cond[1]] == 'O' :
                    tem_map[ten_y][ten_x] = cond[3]
#                   tem_map[-1][0], tem_map[-1][1] = ten_x + cond[1], ten_y + cond[0]
                    queue.append(tem_map[:-1]+[ten_x+cond[1], ten_y+cond[0]])
                print(queue)
                tem_map = 1
                print(ss, "DONE")
        print("while Done")
        #print(queue)
        # 반복문을 전부 읽은 다음 처리하는 듯 하다. 인터프리터는 #############################
        # print()호출 시에는 인스턴스 겹치지 않는다. #############################
### 한 루프 안에 방향을 여러개 두면, 현재 위치를 저장할 수 없다. queue안의 각 데이터별로 x_pos, y_pos이 달라지므로 
### 리스트형 자료 안에 x, y 저장하는 방법 고려해볼 것.
    
    return 0

bfs(map_)
# Out:
# []
# [['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'X', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'X'], [0, 0]] DONE
# [[['D', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'X', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'X'], 0, 1]]
# [['D', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'X', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'X'], [0, 0]] DONE
# [[['D', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'X', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'X'], 0, 1]]
# [['D', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'X', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'X'], [0, 0]] DONE
# ...

# %%
from copy import deepcopy

map_ ='''OOOOO
XOOXO
OOOOO
OOOOO
OOOOX'''

map_list_1 = [list(i) for i in map_.split('\n')]

def check(data) :  # 완료 여부 확인
    count = 0
    for line in data[:-1] :
        if 'O' in line : count += line.count('O')
    if count <= 1 : return True
    else : return False

def search_(li) :
    queue, count = [li+[[0, 0]]], 0
    while len(queue) != 0 :
        head = queue.pop(0)
        if check(head) == True :  # 성공적으로 탐색을 완료한 경우 그 결과를 출력
            count += 1
            print('\n\n'+str(count)+':')
            for RL in head[:-1] :
                print(''.join(RL))
            head = 0
            continue
        for cond in [(-1, 0, 'L', head[-1][0]), (1, 0, 'R', len(head[0])-1-head[-1][0]), (0, -1, 'U', head[-1][1]), (0, 1, 'D', len(head)-2-head[-1][1])] :  # 순서대로 dx, dy, 방향, 좌표가 데이터 범위 내 있을 조건
            head_1 = deepcopy(head)
            if cond[3] > 0 and head_1[head_1[-1][1]+cond[1]][head_1[-1][0]+cond[0]] == 'O' : # 좌표가 데이터 범위 내에 있으면서 탐색 가능한 경우
                head_1[head_1[-1][1]][head_1[-1][0]] = cond[2] #'O'값 방향으로 대체
                head_1[-1][0], head_1[-1][1] = head_1[-1][0]+cond[0], head_1[-1][1]+cond[1] #좌표 갱신
                queue.append(head_1) # queue의 마지막에 추가
search_(map_list_1)
