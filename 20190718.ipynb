# %%
print("="*50, "2019.07.18", "="*50)

import numpy as np
import re
import sys
import pandas as pd

read_data = 0
line_data = 0

ff = open("D:extremum_20190718101759.csv", 'r')

read_data = ff.readlines()  ##file.readlines()는 모든 줄을 읽은 다음, 리스트형 데이터로 리턴

for line_data in read_data :
    print(line_data)

print("done.")
# Out:
# ================================================== 2019.07.18 ==================================================
#
#
# 계급별통계
#
# [검색조건]
#
# ,분류: 지상
#
# ,요소 : 기온
#
# ,검색구분 : 일
#
# ,지역/지점명 : 부산
#
# ,기간 : 2019 ~ 2019년 06 ~ 06월 01 ~ 31일
#
#
#
#
#
#
#
# 		지점번호,지점명,일시,평균기온(℃),최고기온(℃),	최고기온시각,최저기온(℃),최저기온시각
#
# 		159,부산,2019-06-01,19.8,24.8,14:04,16.2,05:13
#
# 		159,부산,2019-06-02,20.9,24.6,10:04,17.4,23:58
#
# 		159,부산,2019-06-03,21.3,25.6,13:26,17.4,00:01
#
# 		159,부산,2019-06-04,23.4,26.5,14:11,19.2,00:01
#
# 		159,부산,2019-06-05,23.9,29.7,09:57,20.4,05:07
#
# 		159,부산,2019-06-06,22.1,27.0,14:09,17.8,23:47
#
# 		159,부산,2019-06-07,18.7,20.0,15:57,16.8,00:25
#
# 		159,부산,2019-06-08,19.1,22.2,14:10,17.0,23:57
#
# 		159,부산,2019-06-09,18.5,22.1,12:42,16.4,02:21
#
# 		159,부산,2019-06-10,18.8,22.7,09:59,15.8,04:48
#
# 		159,부산,2019-06-11,18.5,22.1,09:58,16.1,05:21
#
# 		159,부산,2019-06-12,19.1,22.3,14:29,16.9,03:31
#
# 		159,부산,2019-06-13,19.6,23.0,13:29,15.5,04:42
#
# ...
