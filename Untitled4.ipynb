# %%
#importing packages
import numpy as np
import sys

#date
print("="*50, "2019.06.28", "="*50, "\n\n")

#Data structure : list
#To define the odd
theodd = np.array([1, 3, 5, 7, 9])
print("ODD=", theodd)

#To make the odd even
theeven = theodd+1
print("EVEN=", theeven)

print("\n", "-"*50, "\n")

#To compute SUM
SUM_ODD = 0
count_SUM_ODD = 0

SUM_EVEN = 0
count_SUM_EVEN = 0

for count_SUM_ODD in range(1, 6):
    SUM_ODD = SUM_ODD + theodd[count_SUM_ODD-1]
    count_SUM_ODD += 1
    if count_SUM_ODD == 6:
        break
print("SUM_ODD=", SUM_ODD)

for count_SUM_EVEN in range(1, 6):
    SUM_EVEN = SUM_EVEN + theeven[count_SUM_EVEN-1]
    count_SUM_EVEN += 1
    if count_SUM_EVEN == 6:
        break
print("SUM_EVEN=", SUM_EVEN)

print("-"*50)

#Indexing triple nested list

tnl = [1, 2, ['a', 'b', ['syntax', 'practice']]]
INDEXING_tnl_330=tnl[2][2][0]
print("tnl[2][2][0]=", INDEXING_tnl_330, "\n")

#Functions for list structures
#Reversing, sorting list

rsl = [4, 2, 7, 8, 12, 5, 1666, 6, 35, 77]   #It doesn't work when the list is defined by the numpy package.
rsl.sort()  #'listname.sort' and 'listname.reverse' are function, but don't need variable.
print("list sorted : ", rsl)
rsl.reverse()
print("list reversed : ", rsl)

print("-"*50)

#Data structre : dictionary

DICTIONARY={'KEY1' : 'VALUE1', 'KEY2' : 'VALUE2', 'KEY3' : 'VALUE1', 'KEY4' : 'VALUE4', 'KEY5' : 'VALUE5'}    
DICTIONARY_REFERANCE={'a' : [1, 22, 3]}

count_COMPARISON = 0

for count_COMPARISON in range(2, 6):
    if DICTIONARY['KEY%d' % count_COMPARISON] == DICTIONARY['KEY1']:
        print("The value of KEY%d equals the value of KEY1." %count_COMPARISON)

print("Does 'DICTIONARY' have 'KEY6' as the key?")

'KEY6' in DICTIONARY
# ↑This also can be used for list structure.


print("-"*50)

#Data structure : collections

COLLECTION1 = set("HelloWorld")
COLLECTION1.add('y')
COLLECTION1.update(['hst', 'se', 'value'])

print(COLLECTION1)
list_COLLECTION1 = list(COLLECTION1)
list_COLLECTION1.sort()


COLLECTION2 = set(['H','e','l','l','o','W','o','r','l','d'])
print(COLLECTION2)
list_COLLECTION2 = list(COLLECTION2)
list_COLLECTION2.sort()
print("\n")
print("Sorted list : ")
print(list_COLLECTION1)
print(list_COLLECTION2)
# Out:
# ================================================== 2019.06.28 ==================================================
#
#
# ODD= [1 3 5 7 9]
# EVEN= [ 2  4  6  8 10]
#
#  --------------------------------------------------
#
# SUM_ODD= 25
# SUM_EVEN= 30
# --------------------------------------------------
# tnl[2][2][0]= syntax
#
# list sorted :  [2, 4, 5, 6, 7, 8, 12, 35, 77, 1666]
# list reversed :  [1666, 77, 35, 12, 8, 7, 6, 5, 4, 2]
# --------------------------------------------------
# The value of KEY3 equals the value of KEY1.
# Does 'DICTIONARY' have 'KEY6' as the key?
# --------------------------------------------------
# {'se', 'y', 'l', 'value', 'o', 'r', 'W', 'e', 'd', 'H', 'hst'}
# {'l', 'o', 'r', 'W', 'e', 'd', 'H'}
#
#
# Sorted list :
# ['H', 'W', 'd', 'e', 'hst', 'l', 'o', 'r', 'se', 'value', 'y']
# ['H', 'W', 'd', 'e', 'l', 'o', 'r']
