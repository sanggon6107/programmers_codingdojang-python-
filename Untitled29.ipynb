# %%
from matplotlib import pyplot as plt
import re
import csv

x = [10, 20, 10, 33, 148, 290]

ff = plt.figure(1, figsize = (10, 10))
plt.plot(x)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
