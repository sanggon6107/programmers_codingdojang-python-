# %%
import numpy as np
import pandas as pd
from copy import copy

x1 = open("D:2019.9.19만료자_out.txt", 'r')
yy1 = open("D:2019만료자_out.csv", 'w')


try : 
    
    while True : 
        datax1 = x1.readline()
        datax2 = ", ".join(datax1.split())
        print(datax2)
        yy1.write(datax2)
        yy1.write("\n")

        if not datax1 :
            break;
finally : 
    x1.close()
    yy1.close()
# Out:
# 5103291106213강, 병규, 201703292017032910012647065000부산광역시, 연제구, 연산동, 2647010200264704211223, 5, 1, 쌍미천로152번길
# 6512121108718강, 병규, 201412112014121110012647061000부산광역시, 연제구, 거제동, 쌍용아파트, 104, 1801, 2647010100264703137014, 13, 법원북로
# 5206231108615강, 보형, 201110312011103110602647069000부산광역시, 연제구, 연산동, 일천베스파, 1002, 2647010200264704211031053, 거제천로146번길
# 6507151890013강, 삼중, 201708222017082210012647072000부산광역시, 연제구, 연산동, 더샵파크시티, 112, 901, 2647010200264703130029, 33, 안연로
# 6410071925322강, 신철, 201110312011103110602647062000부산광역시, 연제구, 거제동, 거제동푸르지오, 106, 903, 2647010100264704211246036, 아시아드대로22번길
# 5510301898829강, 익중, 201110312011103110602647072000부산광역시, 연제구, 연산동, 연제타워, 102, 2647010200264704211113021, 과정로294번길
# 6212221120730강, 인섭, 201110312011103110602647070000부산광역시, 연제구, 연산동, 2647010200264704211333066, 월드컵대로46번길
# 6102011815420강, 태성, 201704032017040310012647066000부산광역시, 연제구, 연산동, 2647010200264704211376, 9, 중앙천로25번길
# ...
