# %%
　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　print("="*50, "2019.07.24", "="*50)

import csv
from matplotlib import pyplot as plt

OPU = open("D:20190722103334.csv", 'r')

RI_U = csv.reader(OPU, delimiter = ",")
HEADER = next(RI_U)

extd_X_DATA = 0
X_DATA = []
Y_DATA = []

line_DATA = 0
for line_DATA in RI_U :
    print(line_DATA)     
    
    X_DATA.append(line_DATA[1].split("-")[2])
    Y_DATA.append(line_DATA[-2])
    
OPU.close()

f1 = plt.figure(1, figsize=(15, 10))
plt.subplot(1, 1, 1)
plt.plot(X_DATA, Y_DATA)
plt.title("The Average Temperature On June, 2018")
plt.xlabel("date")
plt.grid(True)
plt.ylabel("Temperature[C]")
plt.legend(['June(2018)'])
plt.show()


print(X_DATA)
print("\n\n", Y_DATA)
# Out:
# ================================================== 2019.07.24 ==================================================
# ['143', '2018-06-01', '24.3', '15.5', '32.2']
# ['143', '2018-06-02', '26.8', '18.8', '33.9']
# ['143', '2018-06-03', '25.2', '18.4', '32.1']
# ['143', '2018-06-04', '25.3', '19.2', '30.8']
# ['143', '2018-06-05', '22.6', '20.4', '26']
# ['143', '2018-06-06', '24.6', '17.6', '31.5']
# ['143', '2018-06-07', '27', '19.6', '33.8']
# ['143', '2018-06-08', '25.6', '21.2', '31.7']
# ['143', '2018-06-09', '20.2', '18', '23.3']
# ['143', '2018-06-10', '18.7', '15.8', '22.4']
# ['143', '2018-06-11', '17', '15.3', '19.6']
# ['143', '2018-06-12', '19.1', '15.2', '25.6']
# ['143', '2018-06-13', '20.3', '17.3', '25.2']
# ['143', '2018-06-14', '20.1', '17.3', '24.2']
# ['143', '2018-06-15', '19.1', '17.2', '23.1']
# ['143', '2018-06-16', '18.7', '16', '22.6']
# ['143', '2018-06-17', '21.9', '13.7', '29']
# ['143', '2018-06-18', '25.4', '18.9', '32.4']
# ...
